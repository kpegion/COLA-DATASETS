# %%
import sys, warnings

import glob
import numpy as np
import datetime
from dateutil.rrule import DAILY,rrule
from time import gmtime, strftime 

#import matplotlib as mpl
import matplotlib.pyplot as plt
#import matplotlib.colors as col
#import matplotlib.cm as cm

import xarray as xr

warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
file_path_name = "/shared/land/SMAP/SPL4SMGP.005/3-hourly/SMAP_L4_SM_gph_20161101T*.h5"
source = xr.open_mfdataset(file_path_name,combine='nested',concat_dim='interval',group='Geophysical_Data')
source
# Out:
# <xarray.Dataset>
# Dimensions:                            (interval: 8, x: 3856, y: 1624)
# Dimensions without coordinates: interval, x, y
# Data variables:
#     baseflow_flux                      (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     heat_flux_ground                   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     heat_flux_latent                   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     heat_flux_sensible                 (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     height_lowatmmodlay                (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     land_evapotranspiration_flux       (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     land_fraction_saturated            (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     land_fraction_snow_covered         (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     land_fraction_unsaturated          (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     land_fraction_wilting              (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     leaf_area_index                    (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     net_downward_longwave_flux         (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     net_downward_shortwave_flux        (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     overland_runoff_flux               (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     precipitation_total_surface_flux   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     radiation_longwave_absorbed_flux   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     radiation_shortwave_downward_flux  (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     sm_profile                         (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     sm_profile_pctl                    (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     sm_profile_wetness                 (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     sm_rootzone                        (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     sm_rootzone_pctl                   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     sm_rootzone_wetness                (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     sm_surface                         (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     sm_surface_wetness                 (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     snow_depth                         (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     snow_mass                          (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     snow_melt_flux                     (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     snowfall_surface_flux              (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     soil_temp_layer1                   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     soil_temp_layer2                   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     soil_temp_layer3                   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     soil_temp_layer4                   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     soil_temp_layer5                   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     soil_temp_layer6                   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     soil_water_infiltration_flux       (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     specific_humidity_lowatmmodlay     (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     surface_pressure                   (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     surface_temp                       (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     temp_lowatmmodlay                  (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     vegetation_greenness_fraction      (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
#     windspeed_lowatmmodlay             (interval, y, x) float32 dask.array<chunksize=(1, 1624, 3856), meta=np.ndarray>
